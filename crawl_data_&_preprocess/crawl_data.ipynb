# %%
import urllib.robotparser
import requests
from bs4 import BeautifulSoup
import time
from selenium import webdriver

# %%
al = urllib.robotparser.RobotFileParser()
al.set_url('https://www.booking.com/robots.txt')
al.read()
al.can_fetch('*','https://www.booking.com/hotel/vn/colline.vi.html?aid=397594;label=gog235jc-1DCAEoggI46AdIKlgDaPQBiAEBmAEquAEXyAEM2AED6AEB-AECiAIBqAIDuAKu4MX_BcACAdICJDNkOTdiNzhhLWU1MGQtNGNlMC04ZmQwLTRhYThkYmJjZGUwMdgCBOACAQ;sid=aa1ef10db21b3c99f2d46d4624c8ebf9;all_sr_blocks=408974501_130057956_0_2_0;checkin=2021-01-03;checkout=2021-01-04;dest_id=-3712045;dest_type=city;dist=0;group_adults=2;group_children=0;hapos=1;highlighted_blocks=408974501_130057956_0_2_0;hp_group_set=0;hpos=1;no_rooms=1;room1=A%2CA;sb_price_type=total;sr_order=popularity;sr_pri_blocks=408974501_130057956_0_2_0__301643900;srepoch=1609658516;srpvid=023133c9b13f00e8;type=total;ucfs=1&#hotelTmpl')
# Out:
# True

# %%
next_page_url = 'https://www.booking.com/searchresults.vi.html?label=gen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ&lang=vi&sid=aa1ef10db21b3c99f2d46d4624c8ebf9&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.vi.html%3Flabel%3Dgen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ%3Bsid%3Daa1ef10db21b3c99f2d46d4624c8ebf9%3Bsb_price_type%3Dtotal%3Bsrpvid%3Df1b8780c7efe01c2%26%3B&ss=TP.+H%C3%B4%CC%80+Chi%CC%81+Minh&is_ski_area=0&ssne=TP.+H%C3%B4%CC%80+Chi%CC%81+Minh&ssne_untouched=TP.+H%C3%B4%CC%80+Chi%CC%81+Minh&dest_id=-3730078&dest_type=city&checkin_year=2021&checkin_month=1&checkin_monthday=5&checkout_year=2021&checkout_month=1&checkout_monthday=6&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1'
# while next_page_url != None:
browser = webdriver.Chrome(executable_path='./chromedriver.exe')
browser.get(next_page_url)
time.sleep(10)
lpage_html = browser.page_source
lpage_tree = BeautifulSoup(lpage_html, 'html.parser')
l_hotels = lpage_tree.find_all('div', {'class': 'sr_property_block_main_row'})
browser.quit()
next_page_url = 'https://www.booking.com' + lpage_tree.find('a', {'title': 'Trang sau'})['href']

# %%
next_page_url = 'https://www.booking.com/searchresults.vi.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ&lang=vi&sid=aa1ef10db21b3c99f2d46d4624c8ebf9&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.vi.html%3Faid%3D304142%3Blabel%3Dgen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ%3Bsid%3Daa1ef10db21b3c99f2d46d4624c8ebf9%3Bsb_price_type%3Dtotal%3Bsrpvid%3D5e934e0e98da00c8%26%3B&ss=%C4%90%C3%A0+N%E1%BA%B5ng&is_ski_area=0&ssne=%C4%90%C3%A0+N%E1%BA%B5ng&ssne_untouched=%C4%90%C3%A0+N%E1%BA%B5ng&dest_id=-3712125&dest_type=city&checkin_year=2021&checkin_month=1&checkin_monthday=6&checkout_year=2021&checkout_month=1&checkout_monthday=7&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1'
page1_out = open('page1_out.csv', 'w', encoding='utf-8')
page1_out.write('City,')
for c in temp_col:
    page1_out.write(f'{c},')
page1_out.write('price\n')  
count = 0
page = 0
while next_page_url != None:
    browser = webdriver.Chrome(executable_path='./chromedriver.exe')
    browser.get(next_page_url)
    time.sleep(10)
    lpage_html = browser.page_source
    lpage_tree = BeautifulSoup(lpage_html, 'html.parser')
    l_hotels = lpage_tree.find_all('div', {'class': 'sr_property_block_main_row'})
    browser.quit()
    next_page_url = 'https://www.booking.com' + lpage_tree.find('a', {'title': 'Trang sau'})['href']
    page+=1

    for i in range(len(l_hotels)):
        hotel_name = l_hotels[i].find('span', {'class': 'sr-hotel__name'}).text.strip()
        browser = webdriver.Chrome(executable_path='./chromedriver.exe')
        hotel_url = 'https://www.booking.com' + l_hotels[i].find('a', {'class': 'js-sr-hotel-link hotel_name_link url'})['href'].strip()
        browser.get(hotel_url)
        time.sleep(10)
        hotel_html = browser.page_source
        hotel_tree = BeautifulSoup(hotel_html, 'html.parser')
        browser.quit()
        flag = 0
        first_room = hotel_tree.find('tr', {'class': 'js-rt-block-row hprt-table-cheapest-block hprt-table-cheapest-block-fix js-hprt-table-cheapest-block'})
        room_fac = hotel_tree.find_all('td', {'class': 'hprt-table-cell -first hprt-table-cell-roomtype droom_seperator'})
        if first_room == None:
            flag = 1
        if flag == 0:
            room = hotel_tree.find_all(lambda tag: tag.name == 'tr' and tag.get('class') == ['js-rt-block-row'])
        else:
            first_room = hotel_tree.find('tr', {'class': 'js-rt-block-row hprt-table-cheapest-block hprt-table-cheapest-block-fix js-hprt-table-cheapest-block hprt-table-last-row'})
            room = hotel_tree.find_all('tr', {'class': 'js-rt-block-row hprt-table-last-row'})
        if first_room == None:
            pass
        else:
            x = first_room.find_all('span', {'class': 'hprt-facilities-facility'})
            y = first_room.find_all('div', {'class': 'hprt-facilities-facility'})
            if len(y) == 0:
                dien_tich = 0
            else:    
                dien_tich = y[0].text.strip()
            page1_out.write('Da Nang,')
            page1_out.write(f'{dien_tich},')
            print(dien_tich)
            faci = []
            for j in range(len(x)):
                faci.append(x[j].text.strip())
                # col.append(x[j].text.strip())
                # print(x[j].text.strip())
            for j in range(1, len(y)):
                faci.append(y[j].text.strip())
                #     col.append(y[j].text.strip())
                # print(y[j].text.strip())
            for c in temp_col:
                if c in faci:
                    page1_out.write(f'{1},')
                else:
                    page1_out.write(f'{0},')
            price = first_room.find('div', {'class': 'hprt-price-block'}).find('div', {'class': 'bui-price-display__value prco-inline-block-maker-helper prco-font16-helper'}).text.strip()[4:]
            page1_out.write(f'{price}\n')
            # breakf = first_room.find('li', {'data-et-mouseenter': 'goal:hp_rt_hovering_mealplan '}).text.strip()
            print(price)
            # print(breakf)
            count+=1
            print(f'---{hotel_name} {count} {page}---')

            for j in range(len(room)):
                if j+1 >= len(room_fac):
                    pass
                else:
                    x1 = room_fac[j+1].find_all('span', {'class': 'hprt-facilities-facility'})
                    y1 = room_fac[j+1].find_all('div', {'class': 'hprt-facilities-facility'})
                if len(y1) == 0:
                    dien_tich = 0
                else:    
                    dien_tich = y1[0].text.strip()
                page1_out.write('Da Nang,')
                page1_out.write(f'{dien_tich},')
                print(dien_tich)
                faci = []
                for k in range(len(x1)):
                    faci.append(x1[k].text.strip())
                    # col.append(x[j].text.strip())
                    # print(x[j].text.strip())
                for k in range(1, len(y1)):
                    faci.append(y1[k].text.strip())
                    #     col.append(y[j].text.strip())
                    # print(y[j].text.strip())
                for c in temp_col:
                    if c in faci:
                        page1_out.write(f'{1},')
                    else:
                        page1_out.write(f'{0},')
                price = room[j].find('div', {'class': 'hprt-price-block'}).find('div', {'class': 'bui-price-display__value prco-inline-block-maker-helper prco-font16-helper'}).text.strip()[4:]
                page1_out.write(f'{price}\n')
                # breakf = room[j].find('li', {'data-et-mouseenter': 'goal:hp_rt_hovering_mealplan '}).text.strip()
                print(price)
                # print(breakf)
                count+=1
                print(f'---{hotel_name} {count} {page}---')

page1_out.close()
# Out:
# n Binh Tai 3079 25---
# 22 m²
# 291.600
# ---An Binh Tai 3080 25---
# 26 m²
# 356.400
# ---An Binh Tai 3081 25---
# 38 m²
# 328.050
# ---An Binh Tai 3082 25---
# 38 m²
# 364.500
# ---An Binh Tai 3083 25---
# 38 m²
# 400.950
# ---An Binh Tai 3084 25---
# 38 m²
# 513.000
# ---An Binh Tai 3085 25---
# 38 m²
# 437.400
# ---An Binh Tai 3086 25---
# 38 m²
# 534.600
# ---An Binh Tai 3087 25---
# 38 m²
# 546.750
# ---An Binh Tai 3088 25---
# 38 m²
# 607.500
# ---An Binh Tai 3089 25---
# 38 m²
# 668.250
# ---An Binh Tai 3090 25---
# 25 m²
# Nhìn ra biển
# 400.000
# ---Hoàng Gia homstay 3413 30---
# Nhìn ra biển
# 1.200.000
# ---Hoàng Gia homstay 3414 30---
# Nhìn ra biển
# 1.440.000
# ---Hoàng Gia homstay 3415 30---
# Nhìn ra biển
# 1.680.000
# ---Hoàng Gia homstay 3416 30---
# Nhìn ra biển
# 1.920.000
# ---Hoàng Gia homstay 3417 30---
# Nhìn ra biển
# 2.160.000
# ---Hoàng Gia homstay 3418 30---
# 400 m²
# 11.270.000
# ---Champa Villa with private pool at Furramar Danang 3419 30---
# 45 m²
# 2.100.000
# ---Sunshine Apartment Near The Beach 3420 30---
# 45 m²
# 2.225.000
# ---Sunshine Apartment Near The Beach 3421 30---
# 60 m²
# 2.350.000
# ---Sunshine Apartment Near The Beach 3422 30---
# 45 m²
# 2.225.000
# ---Sunshine Apartment Near The Beach 3423 30---
# 56 m²
# 2.350.000
# ---Sunshine Apartment Near The Beach 3424 30---
# 50 m²
# 2.470.000
# ---Sunshine Apartment Near The Beach 3425 30---
# 85 m²
# 2.350.000
# ---Sunshine Apartment Near The Beach 3426 30---
# 90 m²
# 2.470.000
# ---Sunshine Apartment Near The Beach 3427 30---
# 70 m²
# 2.525.000
# ---Sunshine Apartment Near The Beach 3428 30---
# 55 m²
# 2.650.000
# ---Sunshine Apartment Near The Beach 3429 30---
# 45 m²
# 3.175.000
# ---Sunshine Apartment Near The Beach 3430 30---
# 45 m²
# 3.300.000
# ---Sunshine Apartment Near The Beach 3431 30---
# 45 m²
# 3.425.000
# ---Sunshine Apartment Near The Beach 3432 30---
# 45 m²
# 3.550.000
# ---Sunshine Apartment Near The Beach 3433 30---
# 45 m²
# 3.200.000
# ---Sunshine Apartment Near The Beach 3434 30---
# 45 m²
# 3.325.000
# ---Sunshine Apartment Near The Beach 3435 30---
# 45 m²
# 3.450.000
# ---Sunshine Apartment Near The Beach 3436 30---
# 45 m²
# 3.410.000
# ---Sunshine Apartment Near The Beach 3437 30---
# 45 m²
# 3.530.000
# ---Sunshine Apartment Near The Beach 3438 30---
# 800 m²
# 7.000.000
# ---BOM HOMES- THE OCEAN VILLAS ĐÀ NẴNg 3439 30---
# 700 m²
# 9.000.000
# ---BOM HOMES- THE OCEAN VILLAS ĐÀ NẴNg 3440 30---
# 20 m²
# 700.000
# ---Zi Coffee & Hostel 3441 30---
# 102 m²
# 2.000.000
# ---Ocean Moon 3442 30---
# 90 m²
# 7.950.000
# ---Luxury Two Bedroom Apartment 3443 30---
# 700 m²
# 8.750.000
# ---Luxury Two Bedroom Apartment 3444 30---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-64be71653525> in <module>
#      15     l_hotels = lpage_tree.find_all('div', {'class': 'sr_property_block_main_row'})
#      16     browser.quit()
# ---> 17     next_page_url = 'https://www.booking.com' + lpage_tree.find('a', {'title': 'Trang sau'})['href']
#      18     page+=1
#      19
#
# TypeError: 'NoneType' object is not subscriptable

# %%
page1_out.close()

# %%
temp_col = col

# %%
temp_col
# Out:
# ['Đồ vệ sinh cá nhân miễn phí',
#  'Vòi sen',
#  'Áo choàng tắm',
#  'Két an toàn',
#  'Nhà vệ sinh',
#  'Khăn tắm',
#  'Bàn làm việc',
#  'Khu vực tiếp khách',
#  'TV',
#  'Dép',
#  'Tủ lạnh',
#  'Điện thoại',
#  'Hệ thống sưởi',
#  'Máy sấy tóc',
#  'Sàn trải thảm',
#  'Ấm đun nước điện',
#  'Truyền hình cáp',
#  'Dịch vụ báo thức',
#  'Tủ hoặc phòng để quần áo',
#  'Giá treo quần áo',
#  'Nhìn ra thành phố',
#  'Bồn tắm',
#  'Điều hòa không khí',
#  'Phòng tắm riêng',
#  'TV màn hình phẳng',
#  'Hệ thống cách âm',
#  'Minibar',
#  'WiFi miễn phí',
#  'Ghế sofa',
#  'Máy fax',
#  'Phòng thay quần áo',
#  'Nhìn ra hồ bơi',
#  'Bếp',
#  'Máy giặt',
#  'Bồn tắm hoặc Vòi sen',
#  'Đồng hồ báo thức',
#  'Bàn ăn',
#  'Bồn tắm spa',
#  'Ổ điện gần giường',
#  'Toilet phụ',
#  'Dịch vụ báo thức',
#  'Giấy vệ sinh',
#  'Phòng tắm riêng trong phòng',
#  'Tiện nghi ủi',
#  'Giường cực dài (> 2 mét)',
#  'Bếp nhỏ',
#  'Khu vực phòng ăn',
#  'Tầm nhìn ra khung cảnh',
#  'Truyền hình vệ tinh',
#  'Bàn ủi',
#  'Ban công',
#  'Nhìn ra sông',
#  'Quyền sử dụng Executive Lounge',
#  'Sàn lát gỗ',
#  'Ra trải giường',
#  'Không gây dị ứng',
#  'Máy pha trà/cà phê',
#  'Khăn tắm/Bộ khăn trải giường (có thu phí)',
#  'Máy sấy quần áo',
#  'Nhìn ra địa danh nổi tiếng',
#  'Phòng tắm phụ',
#  'Có phòng thông nhau qua cửa nối',
#  'Chậu rửa vệ sinh (bidet)',
#  'Lối vào riêng',
#  'Các tầng trên đi lên bằng thang máy',
#  'Xe lăn có thể đi đến mọi nơi trong toàn bộ khuôn viên',
#  'Nhìn ra vườn',
#  'Máy vi tính',
#  'Giường sofa',
#  'Giá phơi quần áo',
#  'Két an toàn cỡ laptop',
#  'Giường xếp',
#  'Quạt máy',
#  'Chăn điện',
#  'Sản phẩm lau rửa',
#  'Ghế cao dành cho trẻ em',
#  'Cửa an toàn cho trẻ nhỏ',
#  'Máy pha Cà phê',
#  'Sàn lát gạch/đá cẩm thạch',
#  'Bàn ủi li quần',
#  'Hoàn toàn nằm ở tầng trệt',
#  'Các tầng trên chỉ lên được bằng cầu thang',
#  'Nắp che ổ cắm điện an toàn',
#  'Đồ bếp',
#  'Đầu đĩa CD',
#  'Máy điều hòa độc lập cho từng phòng',
#  'Nước rửa tay',
#  'Đầu đĩa DVD',
#  'Hồ bơi trên sân thượng',
#  'Ổ cắm cho iPod',
#  'Hồ bơi có tầm nhìn',
#  'Trò chơi board game/giải đố',
#  'Sách, đĩa DVD và nhạc cho trẻ em',
#  'Có lắp đặt máy lọc không khí',
#  'Thiết bị báo carbon monoxide',
#  'Lò vi sóng',
#  'Máy nướng bánh mỳ',
#  'Lò sưởi',
#  'Lò nướng',
#  'Bếp nấu',
#  'Đài radio',
#  'Khu vực ăn uống ngoài trời',
#  'Phòng xông hơi',
#  'Toilet chung',
#  'Bàn ghế ngoài trời',
#  'Bể sục',
#  'Hồ bơi riêng',
#  'Sân trong',
#  'Hướng nhìn sân trong',
#  'Sân hiên']

# %%
browser_temp = webdriver.Chrome(executable_path='./chromedriver.exe')
# url_temp = 'https://www.booking.com/hotel/vn/tan-son-nhat-saigon.vi.html?label=gen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ;sid=aa1ef10db21b3c99f2d46d4624c8ebf9;all_sr_blocks=49942705_86257607_0_1_0;checkin=2021-01-04;checkout=2021-01-05;dest_id=-3730078;dest_type=city;dist=0;group_adults=2;group_children=0;hapos=2;highlighted_blocks=49942705_86257607_0_1_0;hpos=2;no_rooms=1;room1=A%2CA;sb_price_type=total;sr_order=popularity;sr_pri_blocks=49942705_86257607_0_1_0__240500000;srepoch=1609767241;srpvid=20ab5f64fd750074;type=total;ucfs=1&#hotelTmpl'
# url_temp = 'https://www.booking.com/hotel/vn/aem-corner-saigon.vi.html?label=gen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ;sid=aa1ef10db21b3c99f2d46d4624c8ebf9;all_sr_blocks=25182329_86455561_0_2_0;checkin=2021-01-04;checkout=2021-01-05;dest_id=-3730078;dest_type=city;dist=0;group_adults=2;group_children=0;hapos=31;highlighted_blocks=25182329_86455561_0_2_0;hpos=6;no_rooms=1;room1=A%2CA;sb_price_type=total;sr_order=popularity;sr_pri_blocks=25182329_86455561_0_2_0__65000000;srepoch=1609768176;srpvid=f5ea6137ce8d0126;type=total;ucfs=1&#hotelTmpl'

url_temp = 'https://www.booking.com/hotel/vn/sheraton-saigon.vi.html?aid=304142;label=gen173nr-1DCAEoggI46AdIM1gEaPQBiAEBmAEquAEXyAEM2AED6AEBiAIBqAIDuAK9n8v_BcACAdICJGMxZjI0Y2VjLTI2YjMtNGFmNC04M2Y5LWE1YTQyMDA1NmE4ZtgCBOACAQ;sid=aa1ef10db21b3c99f2d46d4624c8ebf9;all_sr_blocks=38081317_246430818_2_41_0;checkin=2021-01-05;checkout=2021-01-06;dest_id=-3730078;dest_type=city;dist=0;group_adults=2;group_children=0;hapos=61;highlighted_blocks=38081317_246430818_2_41_0;hpos=11;no_rooms=1;room1=A%2CA;sb_price_type=total;sr_order=popularity;sr_pri_blocks=38081317_246430818_2_41_0__363825000;srepoch=1609812608;srpvid=50400f3fc2f800c1;type=total;ucfs=1&#hotelTmpl'
browser_temp.get(url_temp)
time.sleep(10)
temp_html = browser_temp.page_source
temp_tree = BeautifulSoup(temp_html, 'html.parser')
browser_temp.quit()

# %%
# price = temp_tree.find_all('td', {'class': 'd_pd_hp_price_left_align hprt-table-cell hprt-table-cell-price'})
# temp_facilities = temp_tree.find_all('td', {'class': 'hprt-table-cell -first hprt-table-cell-roomtype droom_seperator'})
# print(len(price))
# print(len(temp_facilities))
flag = 0
first_room = temp_tree.find('tr', {'class': 'js-rt-block-row hprt-table-cheapest-block hprt-table-cheapest-block-fix js-hprt-table-cheapest-block'})
room_fac = temp_tree.find_all('td', {'class': 'hprt-table-cell -first hprt-table-cell-roomtype droom_seperator'})
if first_room == None:
    flag = 1
# print(flag)
if flag == 0:
    room = temp_tree.find_all(lambda tag: tag.name == 'tr' and tag.get('class') == ['js-rt-block-row'])
else:
    first_room = temp_tree.find('tr', {'class': 'js-rt-block-row hprt-table-cheapest-block hprt-table-cheapest-block-fix js-hprt-table-cheapest-block hprt-table-last-row'})
    room = temp_tree.find_all('tr', {'class': 'js-rt-block-row hprt-table-last-row'})

x = first_room.find_all('span', {'class': 'hprt-facilities-facility'})
y = first_room.find_all('div', {'class': 'hprt-facilities-facility'})
for i in range(len(x)):
    print(x[i].text.strip())
for i in range(1,len(y)):
    dien_tich = y[0].text.strip()
    print(y[i].text.strip())
f_price = first_room.find('div', {'class': 'hprt-price-block'}).find('div', {'class': 'bui-price-display__value prco-inline-block-maker-helper prco-font16-helper'}).text.strip()[4:]
breakf = first_room.find('li', {'data-et-mouseenter': 'goal:hp_rt_hovering_mealplan '}).text.strip()
print(f_price)
print(breakf)
print('------')

for j in range(len(room)):
    x = room_fac[j+1].find_all('span', {'class': 'hprt-facilities-facility'})
    y = room_fac[j+1].find_all('div', {'class': 'hprt-facilities-facility'})
    for i in range(len(x)):
        print(x[i].text.strip())
    for i in range(1,len(y)):
        dien_tich = y[0].text.strip()
        print(y[i].text.strip())
    f_price = room[j].find('div', {'class': 'hprt-price-block'}).find('div', {'class': 'bui-price-display__value prco-inline-block-maker-helper prco-font16-helper'}).text.strip()[4:]
    breakf = room[j].find('li', {'data-et-mouseenter': 'goal:hp_rt_hovering_mealplan '}).text.strip()
    print(f_price)
    print(breakf)
    print('------')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1eac0604f15e> in <module>
#       4 # print(len(temp_facilities))
#       5 flag = 0
# ----> 6 first_room = temp_tree.find('tr', {'class': 'js-rt-block-row hprt-table-cheapest-block hprt-table-cheapest-block-fix js-hprt-table-cheapest-block'})
#       7 room_fac = temp_tree.find_all('td', {'class': 'hprt-table-cell -first hprt-table-cell-roomtype droom_seperator'})
#       8 if first_room == None:
#
# NameError: name 'temp_tree' is not defined

# %%
br_temp = first_room.find('li', {'data-et-mouseenter': 'goal:hp_rt_hovering_mealplan '})
br_temp.text.strip()
# Out:
# 'Bao bữa sáng - Tuyệt vời'
